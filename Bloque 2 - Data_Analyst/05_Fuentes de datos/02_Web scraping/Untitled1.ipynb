# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://reshade.me/compatibility'
r = requests.get(url)

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-GB">
#  <head>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <meta charset="utf-8"/>
#    <base href="https://reshade.me/compatibility"/>
#    <meta content="crosire, reshade, injector, reshade injector, crosire's reshade, crosire's reshade injector, post-processing, post-processing injector, generic depth, sweetfx, mastereffect, gemfx" name="keywords"/>
#    <meta content="ReShade Compatibility List" name="og:title"/>
#    <meta content="article" name="og:type"/>
#    <meta content="https://reshade.me/compatibility" name="og:url"/>
#    <meta content="ReShade" name="og:site_name"/>
#    <meta content="ReShade - Advanced post-processing everywhere." name="og:description"/>
#    <meta content="crosire" name="author"/>
#    <meta content="ReShade - Advanced post-processing everywhere." name="description"/>
# ...

# %%
full_table = soup.find('tbody')

# %%
t_rows = full_table.find_all('tr')

# %%
g_list = []

for row in range(len(t_rows)):
    for element in t_rows[row].find_all('span'):
        print(t_rows[row].find_all('td'))
# Out:
# [<td style="background-color: #000000; text-align: center; width: 33%;"><span style="color: #ffffff; font-weight: bold;">Game</span></td>, <td style="background-color: #000000; text-align: center; width: 12%;"><span style="color: #ffffff; font-weight: bold;">Render API</span></td>, <td style="background-color: #000000; text-align: center; width: 10%;"><span style="color: #ffffff; font-weight: bold;">Status</span></td>, <td style="background-color: #000000; text-align: center; width: 45%;"><span style="color: #ffffff; font-weight: bold;">Additional Notes</span></td>]
# ...

# %%
t_rows[0].find_all('td')
# Out:
# [<td style="background-color: #000000; text-align: center; width: 33%;"><span style="color: #ffffff; font-weight: bold;">Game</span></td>,
#  <td style="background-color: #000000; text-align: center; width: 12%;"><span style="color: #ffffff; font-weight: bold;">Render API</span></td>,
#  <td style="background-color: #000000; text-align: center; width: 10%;"><span style="color: #ffffff; font-weight: bold;">Status</span></td>,
#  <td style="background-color: #000000; text-align: center; width: 45%;"><span style="color: #ffffff; font-weight: bold;">Additional Notes</span></td>]
